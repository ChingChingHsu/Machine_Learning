# %%
#  File: stochastic_gradient_descent.ipynb
#  ----------------------------
#  This file shows student the fundamental concepts of
#  machine learing:
#      - loss function
#      - linear regression
#      - training process

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# This function computes the L2 loss which is
# ----------------------------------------
# [(theta*x_i+b - y_i)**2]
# ----------------------------------------
# of data (x_i, y_i) to the line y_i = theta*x_i + b
#
# theta: float, slop of the line
# b: float, the point on y axis intersects with the line when x_i=0
# x_i: float, 1 data point
# y_i: float, 1 data point
# return: float, the L2 loss of 1 data point

def loss_function(theta, b, x_i, y_i):
    return (theta*x_i+b - y_i)**2

# %%
# You should see 0.25
print(loss_function(0.5, 1.5, 2, 2))
# Out:
# 0.25

# %%
# This function returns the partial derivative of L2 loss function
# with respect to theta:
# --------------------------------------
# 2*(theta*x_i+b - y_i)*x_i
# --------------------------------------
# theta: float, slop of the line
# b: float, the point on y axis intersects with the line when x_i=0
# x_i: float, 1 data point
# y_i: float, 1 data point
# return: float, the dJ_dtheta of 1 data point

def dL_dtheta(theta, b, x_i, y_i):
    return 2*(theta*x_i+b - y_i)*x_i

# %%
# You should see 2.0
print(dL_dtheta(0.5, 1.5, 2, 2))
# Out:
# 2.0

# %%
# This function returns the partial derivative of L2 loss function
# with respect to b:
# --------------------------------------
# 2*(theta*x_i+b - y_i)
# --------------------------------------
# theta: float, slop of the line
# b: float, the point on y axis intersects with the line when x=0
# x_i: float, 1 data point
# y_i: float, 1 data point
# return: float, the dJ_db of 1 data point

def dL_db(theta, b, x_i, y_i):
    return 2*(theta*x_i+b - y_i)*1

# %%
# You should see 1.0
print(dL_db(0.5, 1.5, 2, 2))
# Out:
# 1.0

# %%
x = [6.1101,5.5277,8.5186,7.0032,5.8598,8.3829,7.4764,8.5781,6.4862,5.0546,5.7107,10.164,5.734,8.4084,5.6407,5.3794,6.3654,5.1301,6.4296,7.0708,6.1891]

# %%
y = [6.592,9.1302,13.662,11.854,6.8233,11.886,4.3483,12,6.5987,3.8166,3.2522,15.505,3.1551,7.2258,0.71618,3.5129,5.3048,0.56077,3.6518,5.3893,3.1386]

# %%
# ---------- Showing your data ---------- #

# %%
plt.scatter(x, y)
axes = plt.gca()
axes.set_xlim([0,12])
axes.set_ylim([0,30])
# Out:
# (0.0, 30.0)

# %%
# ---------- Initialize your theta ---------- #

# %%
theta = -2
b = +2

# %%
# ---------- Initialize your alpha ---------- #

# %%
# TODO: which value is appropriate for an ideal alpha?

# %%
alpha = 0.01

# %%
# ---------- Training process ---------- #
# ---- 11 epochs over all data ----- #

# %%
theta_history = []
b_history = []
loss_history = []
cost_history = []
# In SGD, we name '1 iteration through all data' as '1 epoch'!
for epoch in range(11):
  cost = 0
  for i in range(len(x)):
    theta_history.append(theta)
    b_history.append(b)
    loss = loss_function(theta, b, x[i], y[i])
    loss_history.append(loss)
    cost += loss
    # Stochastic Grdient Descent
    theta = theta - alpha*dL_dtheta(theta, b, x[i], y[i])
    b = b - alpha*dL_db(theta, b, x[i], y[i])
    cost_history.append(cost/(2*len(x)))

# %%
# ---------- Theta changes during training process ---------- #

# %%
print(cost_history)
# Out:
# [6.729763543809524, 7.812607268500717, 8.34060182563308, 8.391539913867089, 8.676612230750802, 8.730015897446865, 9.898673242935761, 11.517661393690522, 12.330997167939856, 12.476344218506208, 12.585748002963035, 14.933840058798813, 18.47740391590535, 18.642871940596724, 19.01677165020572, 19.06391382231656, 19.172754136581442, 19.50159961740112, 19.535796613349117, 19.609501616484298, 19.68507775975503, 0.2243446527371647, 0.5503082009153976, 0.71946251245981, 0.7291738010034575, 1.0000759214063963, 1.0428593080398554, 2.17686922700381, 3.764362894062034, 4.539632657670343, 4.6716027612137605, 4.780540180295423, 6.96672610040493, 10.282571122649843, 10.44920300528101, 10.795801881484154, 10.847782388657977, 10.951992723136746, 11.267135364728395, 11.297700890151262, 11.366795903461082, 11.437807659208534, 0.22697677101146763, 0.5610541750880678, 0.704623148135862, 0.7102204568671814, 0.9694422047921512, 1.0029007520806144, 2.103683098095566, 3.6611970180013405, 4.400814004943573, 4.520566163719929, 4.6290569781832325, 6.665470276872282, 9.770124357450532, 9.937875848223538, 10.259275643269815, 10.31611600523131, 10.41598252434276, 10.718263405043041, 10.745539121701572, 10.81035475667622, 10.877124554825361, 0.22951432275100273, 0.5714632842327687, 0.6924745718631515, 0.6951855417435893, 0.9434521412723456, 0.9690465894214073, 2.038440881919685, 3.5674845844661753, 4.273712723103945, 4.382309828580451, 4.490373390262922, 6.388203607235444, 9.296933690329698, 9.465761953502401, 9.763898667842303, 9.825601519099472, 9.921390874895282, 10.211594052831742, 10.235891963063615, 10.296733810784586, 10.359559909988983, 0.23196005470509964, 0.5815407137102546, 0.6827369995520285, 0.683652704964362, 0.921639760244721, 0.9406832245725949, 1.9804152111410231, 3.4824139718072886, 4.1573595734292965, 4.255775339693458, 4.363430129379994, 6.132998998852362, 8.85991097129486, 9.029774659270466, 9.306431748196937, 9.372983084015857, 9.46494384919099, 9.743800522134217, 9.765405455039927, 9.822556041085022, 9.881714407037652, 0.23431669466094718, 0.5912921446990081, 0.6751558849601835, 0.6752434406273009, 0.9035805791520288, 0.9172517289770591, 1.9289411457255778, 3.4052412382295874, 4.050864703291167, 4.1399910221992275, 4.2472546913489175, 5.898084875306761, 8.45621453196636, 8.627073746821427, 8.883894306417961, 8.955265512188323, 9.043629499436861, 9.311821847482335, 9.330993739969118, 9.38471432380804, 9.440460358622827, 0.23658694454437784, 0.6007236760510531, 0.6694997675528584, 0.6696138496922192, 0.8888880858918943, 0.8982432047201812, 1.8834109680291506, 3.33528455634987, 3.9534111759513593, 4.034064870718815, 4.140954281004955, 5.68183259661422, 8.083229361197633, 8.255045615926385, 8.493543588463927, 8.56969327634383, 8.654676756801205, 8.912841491818838, 8.92981748146166, 8.980349712876476, 9.032919847477235, 0.2387734744294312, 0.6098417540553178, 0.6655582992538832, 0.6664516716408846, 0.8772105128186644, 0.8831945326191133, 1.8432694058633738, 3.271919102259897, 3.8642490263891744, 3.937178052616474, 4.043709313407543, 5.482744898248215, 7.738548881527096, 7.911285061165901, 8.132855539147164, 8.213731208780928, 8.295536037484252, 8.54426768235344, 8.559264027465966, 8.606831471468716, 8.656444631960074, 0.24087891736853964, 0.6186531094022756, 0.6631404354000581, 0.6654735635519473, 0.8682278784288991, 0.8716844731730264, 1.8080092485893633, 3.214572362105979, 3.782689800446725, 3.8485789395915555, 3.954767443492628, 5.299445266422061, 7.419958196927444, 7.593578519704316, 7.7995072213448315, 7.885046760037506, 7.963861415702941, 8.203715334515827, 8.216929175570577, 8.261738716365112, 8.30859767447558, 0.24290586496292196, 0.6271647007035612, 0.6620727764099335, 0.6664226062498886, 0.8616492747718151, 0.8633300914263273, 1.7771673241335253, 3.1627198222012587, 3.7081015380456974, 3.767577624694815, 3.8734380812611473, 5.130668173755806, 7.125418692811003, 7.299888671447534, 7.491360654492745, 7.581493690931206, 7.657494236765 ...

# %%
theta = theta_history[0]
b = b_history[0]

print(f'theta: {theta}, b = {b}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot + b


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("1 data", color='red', fontdict = {'fontsize': 20})
plt.show()
# Out:
# theta: -2, b = 2

# %%
theta = theta_history[1]
b = b_history[1]

print(f'theta: {theta}, b = {b}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot + b


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("2 data", color='red', fontdict = {'fontsize': 20})
plt.show()
# Out:
# theta: 0.05448446440000021, b = 2.085181889481391

# %%
theta = theta_history[2]
b = b_history[2]

print(f'theta: {theta}, b = {b}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot + b


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("3 data", color='red', fontdict = {'fontsize': 20})
plt.show()
# Out:
# theta: 0.8000434311945271, b = 2.1376342501994836

# %%
theta = theta_history[3]
b = b_history[3]

print(f'theta: {theta}, b = {b}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot + b


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("4 data", color='red', fontdict = {'fontsize': 20})
plt.show()
# Out:
# theta: 1.6023449043240658, b = 2.0951268591559944

# %%
theta = theta_history[4]
b = b_history[4]

print(f'theta: {theta}, b = {b}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot + b


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("5 data", color='red', fontdict = {'fontsize': 20})
plt.show()
# Out:
# theta: 1.3974776764911454, b = 2.0945680086928187

# %%
theta = theta_history[5]
b = b_history[5]

print(f'theta: {theta}, b = {b}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot + b


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("6 data", color='red', fontdict = {'fontsize': 20})
plt.show()
# Out:
# theta: 0.9919551751871669, b = 2.072889469807727

# %%
# ---------- Plot the errors over the training process ---------- #

# %%
plot_x = list(range(len(cost_history)))
plot_y = cost_history
plt.plot(plot_x, plot_y)
plt.title("Errors over epochs", color = 'blue')
# Out:
# Text(0.5, 1.0, 'Errors over epochs')

# %%
if b > 0:
    print(f'############ Final equation: y = {theta_history[-1]}x+{b} ############')
else:
    print(f'############ Final equation: y = {theta_history[-1]}x{b} ############')
# Out:
# ############ Final equation: y = 1.0480021966111333x+2.072889469807727 ############

# %%
theta = theta_history[-1]
b = b_history[-1]

print(f'theta: {theta}, b = {b}')

x_plot = np.linspace(0, 12, 140)
y_plot = theta*x_plot + b


plt.scatter(x_plot, y_plot, s=8, color='red')
plt.scatter(x, y, color='blue')

plt.title("Final Model", color='red', fontdict = {'fontsize': 20})
plt.show()
# Out:
# theta: 1.0480021966111333, b = -2.0210099720738284

# %%
x_unseen = 4

# %%
prediction = theta*x_unseen + b

# %%
prediction
# Out:
# 2.1709988143707046
